# %% [markdown]
# # Библиотека Pandas

# %% [markdown]
# ###   Подключение библиотеки

# %%
import pandas as pd

# %%
np.random.seed(1)

# %% [markdown]
# ### Создание датафреймов

# %%
a = np.random.randint(10, size=(9, 9))
df = pd.DataFrame(a, columns = [ chr( i + 97 ) for i in range(9) ])
df
# Out:
#    a  b  c  d  e  f  g  h  i
# 0  2  2  6  6  0  1  5  6  5
# 1  8  8  5  5  7  5  9  1  3
# 2  9  3  3  3  6  1  3  0  5
# 3  0  5  2  7  6  4  0  2  4
# 4  8  7  6  7  7  1  7  7  3
# 5  8  3  0  6  3  0  6  5  9
# 6  6  4  6  6  2  2  4  1  2
# 7  3  9  3  6  7  0  3  3  6
# 8  8  6  5  1  3  2  6  3  6

# %% [markdown]
# ### Вывод первых 5 строк

# %%
df.head()
# Out:
#    a  b  c  d  e  f  g  h  i
# 0  2  2  6  6  0  1  5  6  5
# 1  8  8  5  5  7  5  9  1  3
# 2  9  3  3  3  6  1  3  0  5
# 3  0  5  2  7  6  4  0  2  4
# 4  8  7  6  7  7  1  7  7  3

# %% [markdown]
# ### Создание серии

# %%
a = np.random.randint(10, size = 9)
se = pd.Series(a)
se
# Out:
# 0    7
# 1    2
# 2    8
# 3    0
# 4    1
# 5    8
# 6    6
# 7    0
# 8    0
# dtype: int32

# %% [markdown]
# ### Каждые строка и столбец - серия. Обращение к столбцу по его имени

# %%
df['a']
# Out:
# 0    2
# 1    8
# 2    9
# 3    0
# 4    8
# 5    8
# 6    6
# 7    3
# 8    8
# Name: a, dtype: int32

# %% [markdown]
# ### или

# %%
df.a
# Out:
# 0    2
# 1    8
# 2    9
# 3    0
# 4    8
# 5    8
# 6    6
# 7    3
# 8    8
# Name: a, dtype: int32

# %% [markdown]
# ### Выбрать несколько столбцов

# %%
df[['a' , 'b']]
# Out:
#    a  b
# 0  2  2
# 1  8  8
# 2  9  3
# 3  0  5
# 4  8  7
# 5  8  3
# 6  6  4
# 7  3  9
# 8  8  6

# %% [markdown]
# ### Обращение к указанной строке

# %%
df.iloc[1]
# Out:
# a    8
# b    8
# c    5
# d    5
# e    7
# f    5
# g    9
# h    1
# i    3
# Name: 1, dtype: int32

# %% [markdown]
# ### Обращение к указанному столбцу указанной строки и наоборот

# %%
print( df.iloc[5]['a'], df['a'].iloc[5] )
# Out:
# 8 8

# %% [markdown]
# ### или

# %%
df.loc[5,'a']
# Out:
# 8

# %% [markdown]
# ### Вывод формы и количества элементов датафрейма

# %%
print( df.shape )
print( df.size )
# Out:
# (9, 9)
# 81

# %% [markdown]
# ### Найти все строки, в которых в столбце a стоит значение 4

# %%
df[ df.a==4 ]
# Out:
# Empty DataFrame
# Columns: [a, b, c, d, e, f, g, h, i]
# Index: []

# %% [markdown]
# ### Срез данных

# %%
df[3:5]
# Out:
#    a  b  c  d  e  f  g  h  i
# 3  0  5  2  7  6  4  0  2  4
# 4  8  7  6  7  7  1  7  7  3

# %% [markdown]
# ### Сохранение и загрузка базы данных в формате .csv

# %%
df.to_csv('example.csv')
df = pd.read_csv('example.csv', index_col = 0)
df
# Out:
#    a  b  c  d  e  f  g  h  i
# 0  2  2  6  6  0  1  5  6  5
# 1  8  8  5  5  7  5  9  1  3
# 2  9  3  3  3  6  1  3  0  5
# 3  0  5  2  7  6  4  0  2  4
# 4  8  7  6  7  7  1  7  7  3
# 5  8  3  0  6  3  0  6  5  9
# 6  6  4  6  6  2  2  4  1  2
# 7  3  9  3  6  7  0  3  3  6
# 8  8  6  5  1  3  2  6  3  6

# %% [markdown]
# ### Сохранение и загрузка базы данных в формате .xlsx

# %%
df.to_csv('example.xlsx')
df = pd.read_csv('example.xlsx', index_col = 0)
df
# Out:
#    a  b  c  d  e  f  g  h  i
# 0  2  2  6  6  0  1  5  6  5
# 1  8  8  5  5  7  5  9  1  3
# 2  9  3  3  3  6  1  3  0  5
# 3  0  5  2  7  6  4  0  2  4
# 4  8  7  6  7  7  1  7  7  3
# 5  8  3  0  6  3  0  6  5  9
# 6  6  4  6  6  2  2  4  1  2
# 7  3  9  3  6  7  0  3  3  6
# 8  8  6  5  1  3  2  6  3  6

# %% [markdown]
# ### Получить названия столбцов и индексы строк

# %%
print( df.columns )
print( df.index )
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'], dtype='object')
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %% [markdown]
# ### Типы переменных для каждой строки

# %%
df.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# d    int64
# e    int64
# f    int64
# g    int64
# h    int64
# i    int64
# dtype: object

# %% [markdown]
# ### Информация о базе данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       9 non-null      int64
#  1   b       9 non-null      int64
#  2   c       9 non-null      int64
#  3   d       9 non-null      int64
#  4   e       9 non-null      int64
#  5   f       9 non-null      int64
#  6   g       9 non-null      int64
#  7   h       9 non-null      int64
#  8   i       9 non-null      int64
# dtypes: int64(9)
# memory usage: 720.0 bytes

# %% [markdown]
# ### Количество непропущенных значений (count), среднее арифметическое (mean), стандартное отклонение (std), минимальное значение (min), квартиль 0.25 (25%), медиана (50%), квартиль 0.75 (75%), максимальное значение (max) по столбцам

# %%
df.describe()
# Out:
#               a         b        c         d         e         f         g  \
# count  9.000000  9.000000  9.00000  9.000000  9.000000  9.000000  9.000000
# mean   5.777778  5.222222  4.00000  5.222222  4.555556  1.777778  4.777778
# std    3.270236  2.438123  2.12132  1.986063  2.603417  1.715938  2.635231
# min    0.000000  2.000000  0.00000  1.000000  0.000000  0.000000  0.000000
# 25%    3.000000  3.000000  3.00000  5.000000  3.000000  1.000000  3.000000
# 50%    8.000000  5.000000  5.00000  6.000000  6.000000  1.000000  5.000000
# 75%    8.000000  7.000000  6.00000  6.000000  7.000000  2.000000  6.000000
# max    9.000000  9.000000  6.00000  7.000000  7.000000  5.000000  9.000000
#
#               h         i
# count  9.000000  9.000000
# mean   3.111111  4.777778
# std    2.420973  2.108185
# min    0.000000  2.000000
# 25%    1.000000  3.000000
# 50%    3.000000  5.000000
# 75%    5.000000  6.000000
# max    7.000000  9.000000

# %% [markdown]
# ### Уникальные значения серии

# %%
df['a'].unique()
# Out:
# array([2, 8, 9, 0, 6, 3], dtype=int64)

# %% [markdown]
# ### Количество значений

# %%
df['a'].value_counts()
# Out:
# 8    4
# 2    1
# 9    1
# 0    1
# 6    1
# 3    1
# Name: a, dtype: int64

# %% [markdown]
# ### Фильтрация по значениям столбцов

# %%
df[ ( df['a']>1 ) & ( df['b']<5 ) ]
# Out:
#    a  b  c  d  e  f  g  h  i
# 0  2  2  6  6  0  1  5  6  5
# 2  9  3  3  3  6  1  3  0  5
# 5  8  3  0  6  3  0  6  5  9
# 6  6  4  6  6  2  2  4  1  2

# %% [markdown]
# ### Сортировка по значениям столбца

# %%
df_ = df.sort_values(['a'])
df_
# Out:
#    a  b  c  d  e  f  g  h  i
# 3  0  5  2  7  6  4  0  2  4
# 0  2  2  6  6  0  1  5  6  5
# 7  3  9  3  6  7  0  3  3  6
# 6  6  4  6  6  2  2  4  1  2
# 1  8  8  5  5  7  5  9  1  3
# 4  8  7  6  7  7  1  7  7  3
# 5  8  3  0  6  3  0  6  5  9
# 8  8  6  5  1  3  2  6  3  6
# 2  9  3  3  3  6  1  3  0  5

# %% [markdown]
# ### Сортировка по индексам строк

# %%
df_ = df.sort_index(axis=1)
df_
# Out:
#    a  b  c  d  e  f  g  h  i
# 0  2  2  6  6  0  1  5  6  5
# 1  8  8  5  5  7  5  9  1  3
# 2  9  3  3  3  6  1  3  0  5
# 3  0  5  2  7  6  4  0  2  4
# 4  8  7  6  7  7  1  7  7  3
# 5  8  3  0  6  3  0  6  5  9
# 6  6  4  6  6  2  2  4  1  2
# 7  3  9  3  6  7  0  3  3  6
# 8  8  6  5  1  3  2  6  3  6

# %% [markdown]
# ### Выбор колонки в качестве индекса

# %%
df2 = df.set_index('a')
df2
# Out:
#    b  c  d  e  f  g  h  i
# a
# 2  2  6  6  0  1  5  6  5
# 8  8  5  5  7  5  9  1  3
# 9  3  3  3  6  1  3  0  5
# 0  5  2  7  6  4  0  2  4
# 8  7  6  7  7  1  7  7  3
# 8  3  0  6  3  0  6  5  9
# 6  4  6  6  2  2  4  1  2
# 3  9  3  6  7  0  3  3  6
# 8  6  5  1  3  2  6  3  6

# %% [markdown]
# ### Сброс индексов

# %%
df2 = df2.reset_index()
df2
# Out:
#    a  b  c  d  e  f  g  h  i
# 0  2  2  6  6  0  1  5  6  5
# 1  8  8  5  5  7  5  9  1  3
# 2  9  3  3  3  6  1  3  0  5
# 3  0  5  2  7  6  4  0  2  4
# 4  8  7  6  7  7  1  7  7  3
# 5  8  3  0  6  3  0  6  5  9
# 6  6  4  6  6  2  2  4  1  2
# 7  3  9  3  6  7  0  3  3  6
# 8  8  6  5  1  3  2  6  3  6

# %% [markdown]
# ### Формат даты и времени

# %%
import datetime as dt
Y = [ str(random.randrange(1990,2022,1))
     + "-"
     + str(random.randrange(1,12,1))
     + "-"
     + str(random.randrange(1,31,1))
     for i in range(10) ]
Y
# Out:
# ['2019-9-10',
#  '2019-1-8',
#  '1999-7-13',
#  '1992-4-27',
#  '1991-6-12',
#  '2008-11-21',
#  '1998-7-24',
#  '2011-10-20',
#  '1990-6-29',
#  '1999-11-6']

# %%
df1 = pd.DataFrame({'a':Y})
df1
# Out:
#             a
# 0   2019-9-10
# 1    2019-1-8
# 2   1999-7-13
# 3   1992-4-27
# 4   1991-6-12
# 5  2008-11-21
# 6   1998-7-24
# 7  2011-10-20
# 8   1990-6-29
# 9   1999-11-6

# %%
df1['a'] = pd.to_datetime(df1['a'])
df1
# Out:
#            a
# 0 2019-09-10
# 1 2019-01-08
# 2 1999-07-13
# 3 1992-04-27
# 4 1991-06-12
# 5 2008-11-21
# 6 1998-07-24
# 7 2011-10-20
# 8 1990-06-29
# 9 1999-11-06

# %%
df1['a'][5].year, df1['a'][5].month, df1['a'][5].day
# Out:
# (2008, 11, 21)

# %% [markdown]
# ###  Работа с пустыми значениями

# %%
df2 = df[['a' , 'b']][0:5].copy()

df2.loc[0 , 'a'] = None
df2.loc[1 , 'b'] = None

df2
# Out:
#      a    b
# 0  NaN  2.0
# 1  8.0  NaN
# 2  9.0  3.0
# 3  0.0  5.0
# 4  8.0  7.0

# %%
df2.isnull()
# Out:
#        a      b
# 0   True  False
# 1  False   True
# 2  False  False
# 3  False  False
# 4  False  False

# %%
df2.dropna()
# Out:
#      a    b
# 2  9.0  3.0
# 3  0.0  5.0
# 4  8.0  7.0

# %%
df2.fillna(0)
# Out:
#      a    b
# 0  0.0  2.0
# 1  8.0  0.0
# 2  9.0  3.0
# 3  0.0  5.0
# 4  8.0  7.0

# %%
df2.fillna(method='ffill')
# Out:
#      a    b
# 0  NaN  2.0
# 1  8.0  2.0
# 2  9.0  3.0
# 3  0.0  5.0
# 4  8.0  7.0

# %%
df2.fillna(method='bfill')
# Out:
#      a    b
# 0  8.0  2.0
# 1  8.0  3.0
# 2  9.0  3.0
# 3  0.0  5.0
# 4  8.0  7.0

# %%
df2.fillna(df.median())
# Out:
#      a    b
# 0  8.0  2.0
# 1  8.0  5.0
# 2  9.0  3.0
# 3  0.0  5.0
# 4  8.0  7.0

# %%
df2.fillna(df.mean())
# Out:
#           a         b
# 0  5.777778  2.000000
# 1  8.000000  5.222222
# 2  9.000000  3.000000
# 3  0.000000  5.000000
# 4  8.000000  7.000000

# %% [markdown]
# # Домашнее задание
